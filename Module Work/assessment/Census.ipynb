# %%
# Dependencies
import numpy as np
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Census_Data.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# []

# %%
# Save references to each table
census_data = Base.classes.Census_Data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'Census_Data'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6b1d6538c20b> in <module>
#       1 # Save references to each table
# ----> 2 census_cata = Base.classes.Census_Data
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# ...

# %%
df = pd.read_sql_query("SELECT * FROM Census_Data", engine)

# %%
df
# Out:
#                  CityState               city state  Population  \
# 0              HOUSTON, TX            HOUSTON    TX     3061887
# 1              CHICAGO, IL            CHICAGO    IL     2702091
# 2             BROOKLYN, NY           BROOKLYN    NY     2595259
# 3          LOS ANGELES, CA        LOS ANGELES    CA     2426413
# 4                MIAMI, FL              MIAMI    FL     1820704
# ..                     ...                ...   ...         ...
# 994  ALTAMONTE SPRINGS, FL  ALTAMONTE SPRINGS    FL       56883
# 995        CHILLICOTHE, OH        CHILLICOTHE    OH       56783
# 996         FARMINGTON, NM         FARMINGTON    NM       56781
# 997          FAIRFIELD, CT          FAIRFIELD    CT       56704
# 998   DEARBORN HEIGHTS, MI   DEARBORN HEIGHTS    MI       56656
#
#      White Population  Black Population  Native American Population  \
# 0             1775897            684416                       11586
# ...

# %%
#cities over 100K
#youngest median pop

newdf = df[df['Population'] >= 100000]

# %%
result = newdf.sort_values(by=['Median Age'])

# %%
result
# Out:
#                CityState             city state  Population  White Population  \
# 357            PROVO, UT            PROVO    UT      115828            102237
# 337           ATHENS, GA           ATHENS    GA      120952             79691
# 301      BLOOMINGTON, IN      BLOOMINGTON    IN      130817            112800
# 376  COLLEGE STATION, TX  COLLEGE STATION    TX      112074             89674
# 260         COLUMBIA, MO         COLUMBIA    MO      146510            116562
# ..                   ...              ...   ...         ...               ...
# 329       TOMS RIVER, NJ       TOMS RIVER    NJ      122901            110183
# 394       VERO BEACH, FL       VERO BEACH    FL      108337             92955
# 127         SARASOTA, FL         SARASOTA    FL      238533            215488
# 96            NAPLES, FL           NAPLES    FL      292357            259793
# 378     DELRAY BEACH, FL     DELRAY BEACH    FL      111631             84061
#
# ...
